# %%
import templateflow.api as tflow
from nilearn.surface import SurfaceImage, load_surf_data
import matplotlib.pyplot as plt
from nilearn.datasets import load_fsaverage_data
from nilearn.plotting import plot_surf_roi, show
import pandas as pd

template = "fsaverage"

# 只使用 10k 密度
density = "10k"

mesh = {}
data = {}
for hemi in ["left", "right"]:
    mesh[hemi] = tflow.get(
        template,
        extension="surf.gii",
        suffix="pial",
        density=density,
        hemi=hemi[0].upper(),
    )

    roi_data = load_surf_data(
        tflow.get(
            template,
            atlas="Desikan2006",
            density=density,
            hemi=hemi[0].upper(),
            extension="label.gii",
        )
    )

    data[hemi] = roi_data

desikan_10k = SurfaceImage(mesh=mesh, data=data)

# 创建单个图
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

fs_density = {
    "3k": "fsaverage4",
    "10k": "fsaverage5",
    "41k": "fsaverage6",
    "164k": "fsaverage",
}

sulcal_depth_map = load_fsaverage_data(
    mesh=fs_density[density], data_type="sulcal"
)

lut = tflow.get(
    template,
    atlas="Desikan2006",
    suffix="dseg",
    extension="tsv",
)
lut= pd.read_csv(lut, sep='\t')

print(lut)

plot_surf_roi(
    roi_map=desikan_10k,
    cmap=lut,
    bg_map=sulcal_depth_map,
    bg_on_data=True,
    title=f"DK atlas ({density})",
    axes=ax,
    view='lateral',  # 设置视角：'lateral', 'medial', 'dorsal', 'ventral', 'anterior', 'posterior'
)

show()
# Out:
# /root/.cache/templateflow/tpl-fsaverage/tpl-fsaverage_atlas-Desikan2006_dseg.tsv
# /tmp/ipykernel_1864/85008768.py:61: DeprecationWarning: The `darkness` parameter will be deprecated in release 0.13. We recommend setting `darkness` to None
#   plot_surf_roi(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 61
#      52 lut = tflow.get(
#      53     template,
#      54     atlas="Desikan2006",
#      55     suffix="dseg",
#      56     extension="tsv",
#      57 )
#      59 print(lut)
# ---> 61 plot_surf_roi(
#      62     roi_map=desikan_10k,
#      63     cmap=lut,
#      64     bg_map=sulcal_depth_map,
#      65     bg_on_data=True,
#      66     title=f"DK atlas ({density})",
#      67     axes=ax,
#      68     view='lateral',  # 设置视角：'lateral', 'medial', 'dorsal', 'ventral', 'anterior', 'posterior'
#      69 )
#      71 show()
#
# File ~/miniconda3/lib/python3.12/site-packages/nilearn/plotting/surface/surf_plotting.py:1051, in plot_surf_roi(surf_mesh, roi_map, bg_map, hemi, view, engine, cmap, colorbar, avg_method, threshold, alpha, bg_on_data, darkness, vmin, vmax, cbar_tick_format, title, title_font_size, output_file, axes, figure, **kwargs)
#    1048 backend = get_surface_backend(engine)
#    1049 backend._adjust_plot_roi_params(params)
# -> 1051 fig = backend._plot_surf(
#    1052     mesh,
#    1053     surf_map=roi,
#    1054     bg_map=bg_map,
#    1055     hemi=hemi,
#    1056     view=view,
#    1057     cmap=cmap,
#    1058     colorbar=colorbar,
#    1059     avg_method=params["avg_method"],
#    1060     threshold=threshold,
#    1061     alpha=alpha,
#    1062     bg_on_data=bg_on_data,
#    1063     darkness=darkness,
#    1064     vmin=vmin,
#    1065     vmax=vmax,
#    1066     cbar_tick_format=params["cbar_tick_format"],
#    1067     title=title,
#    1068     title_font_size=title_font_size,
#    1069     output_file=output_file,
#    1070     axes=axes,
#    1071     figure=figure,
#    1072     **kwargs,
#    1073 )
#    1074 return fig
#
# File ~/miniconda3/lib/python3.12/site-packages/nilearn/plotting/surface/_matplotlib_backend.py:562, in _plot_surf(surf_mesh, surf_map, bg_map, hemi, view, cmap, symmetric_cmap, colorbar, avg_method, threshold, alpha, bg_on_data, darkness, vmin, vmax, cbar_vmin, cbar_vmax, cbar_tick_format, title, title_font_size, output_file, axes, figure)
#     551 surf_map_faces = _compute_surf_map_faces(
#     552     surf_map,
#     553     faces,
#    (...)    556     bg_face_colors.shape[0],
#     557 )
#     558 surf_map_faces, kept_indices, vmin, vmax = _threshold_and_rescale(
#     559     surf_map_faces, threshold, vmin, vmax
#     560 )
# --> 562 surf_map_face_colors = cmap(surf_map_faces)
#     563 # set transparency of voxels under threshold to 0
#     564 surf_map_face_colors[~kept_indices, 3] = 0
#
# TypeError: 'PosixPath' object is not callable
